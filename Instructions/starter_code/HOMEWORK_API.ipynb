# %% [markdown]
# # WeatherPy_HW_Vojvodic
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #### Dependencies and Setup
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import pytemperature
import logging




# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 662

# %%
# new = cities + countries
# cities= list(zip(cities,countries))
len(cities)
# Out:
# 662

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# citi = cities
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
owm.utils.load_config
settings = {"units": units, "APPID": api_key}
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
weather_response = []
cityList = []
citNam = []
lat = []
temp = []
humi = []
eSea = []
eGnd = []
clouds = []
wind = []
code = []

# for citi in cities:
#     weather_response = owm.find_city(citi, **settings)
#     selection = ('id','coord.lat','coord.lon')
#     data = weather_response(selection)
#     cityList.append(data)
    
# Loop through the list of cities and perform a request for data on each
# for city in cities:
#     response = requests.get(query_url + city).json()
#     lat.append(response['coord']['lat'])
#     temp.append(response['main']['temp'])
#     cloud.append(response['clouds']['all'])
#     wind.append(response['wind']['speed'])
# logger.disabled = True
# logger.disabled = False

# cnt=1
for city in cities:
    logger = logging.log(1,"logging.debug")
#     print(logging)
    response = requests.get(query_url + city).json()
    response1=response
    try:    
        print(f"For the city named {(response1['name'])}, ID Number-{(response1['id'])}: LAT={(response1['coord']['lat'])} WIND={(response1['wind']['speed'])} HUMIDITY={(response['main']['humidity'])} TEMP={(response1['main']['temp_max'])} CLOUDINESS={(response1['clouds']['all'])}")
        response1=[]
        citNam.append(response['name']) #and citNam.append(cnt)
        code.append(response['id'])
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        humi.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        eSea.append(response['main']['sea_level'])
        eGnd.append(response['main']['grnd_level'])

    except KeyError:
#             print(f"The NAME is NO GOOD")
            next
#     print(f"The {code} information received is: {wind}")
#     print(f"The latitude information received is: {lat}")
#     print(f"The temperature information received is: {temp}")
#     print(f"The cloud information received is: {cloud}")
#     print(f"The wind information received is: {wind}")

#     print(f"The {city} latitude information received is: {lat}")
#     print(f"The  {city} temperature information received is: {temp}")
#     print(f"The  {city} cloud information received is: {cloud}")
#     print(f"The  {city} wind information received is: {wind}")
    
# # loop throught the list of units and append them to cityList list
# for citi in cities:
#     query_url = f"{url}appid={api_key}&q={citi}"
#     weather_response = requests.get(query_url)
#     response= weather_response.json()
#     lat.append(response['coord']['lat'])
#     temp.append(response['main']['temp'])
#     cloud.append(response['clouds']['all'])
#     wind.append(response['wind']['speed'])
#     cityList.append(weather_json)
    
#     for city in cities:
#     response = requests.get(query_url + city).json()
#     selection = ('name','id','coord.lat','coord.lon',"main.temp", 'main.temp_max',"main.humidity", "wind.speed",'clouds.all')
# Out:
# For the city named Puerto Ayora, ID Number-3652764: LAT=-0.74 WIND=10.29 HUMIDITY=88 TEMP=69.8 CLOUDINESS=75
# For the city named Umm Kaddadah, ID Number-364933: LAT=13.6 WIND=8.16 HUMIDITY=26 TEMP=96.21 CLOUDINESS=3
# For the city named Hobart, ID Number-2163355: LAT=-42.88 WIND=8.05 HUMIDITY=65 TEMP=44.6 CLOUDINESS=75
# For the city named Klecany, ID Number-3073652: LAT=50.18 WIND=11.41 HUMIDITY=31 TEMP=91 CLOUDINESS=0
# For the city named Tuktoyaktuk, ID Number-6170031: LAT=69.44 WIND=10.29 HUMIDITY=93 TEMP=50 CLOUDINESS=90
# For the city named Torbay, ID Number-6167817: LAT=47.66 WIND=9.17 HUMIDITY=82 TEMP=69.01 CLOUDINESS=75
# For the city named Sur, ID Number-286245: LAT=22.57 WIND=10.85 HUMIDITY=70 TEMP=82.17 CLOUDINESS=0
# For the city named Katherine, ID Number-2068655: LAT=-14.47 WIND=8.05 HUMIDITY=27 TEMP=60.8 CLOUDINESS=0
# For the city named Wangaratta, ID Number-2144764: LAT=-36.36 WIND=17.22 HUMIDITY=81 TEMP=51.8 CLOUDINESS=75
# For the city named Georgetown, ID Number-3378644: LAT=6.8 WIND=6.93 HUMIDITY=83 TEMP=82.4 CLOUDINESS=40
# For the city named Ugoofaaru, ID Number-1337619: LAT=5.67 WIND=13 HUMIDITY=73 TEMP=83.43 CLOUDINESS=100
# For the city named Busselton, ID Number-2075265: LAT=-33.64 WIND=6.42 HUMIDITY=60 TEMP=59 CLOUDINESS=100
# For the city named Lebu, ID Number-344979: LAT=8.96 WIND=9.17 HUMIDITY=60 TEMP=69.8 CLOUDINESS=75
# For the city named Avarua, ID Number-4035715: LAT=-21.21 WIND=14.99 HUMIDITY=69 TEMP=73.4 CLOUDINESS=2
# For the city named Yellowknife, ID Number-6185377: LAT=62.45 WIND=6.93 HUMIDITY=63 TEMP=68 CLOUDINESS=20
# For the city named Jamestown, ID Number-2069194: LAT=-33.21 WIND=10.09 HUMIDITY=94 TEMP=51.57 CLOUDINESS=97
# For the city named New Norfolk, ID Number-2155415: LAT=-42.78 WIND=8.05 HUMIDITY=65 TEMP=44.6 CLOUDINESS=75
# For the city named Port Alfred, ID Number-964432: LAT=-33.59 WIND=14.16 HUMIDITY=59 TEMP=70 CLOUDINESS=0
# For the city named Butaritari, ID Number-2110227: LAT=3.07 WIND=8.1 HUMIDITY=72 TEMP=84.33 CLOUDINESS=100
# For the city named Nicoya, ID Number-3622716: LAT=10.15 WIND=5.82 HUMIDITY=74 TEMP=82.4 CLOUDINESS=0
# For the city named Issoire, ID Number-3012664: LAT=45.54 WIND=4.7 HUMIDITY=14 TEMP=100.4 CLOUDINESS=0
# For the city named Panjab, ID Number-1131162: LAT=34.38 WIND=17.9 HUMIDITY=31 TEMP=63.45 CLOUDINESS=19
# For the city named Katsuura, ID Number-1865309: LAT=33.93 WIND=1.12 HUMIDITY=88 TEMP=78.8 CLOUDINESS=75
# For the city named Nove Mesto na Morave, ID Number-3069465: LAT=49.56 WIND=12.75 HUMIDITY=37 TEMP=88 CLOUDINESS=0
# For the city named Thompson, ID Number-6165406: LAT=55.74 WIND=3.36 HUMIDITY=82 TEMP=62.6 CLOUDINESS=40
# For the city named Port Elizabeth, ID Number-4501427: LAT=39.31 WIND=9.17 HUMIDITY=94 TEMP=72 CLOUDINESS=90
# For the city named Bathsheba, ID Number-3374083: LAT=13.22 WIND=17.22 HUMIDITY=74 TEMP=86 CLOUDINESS=40
# For the city named Vanimo, ID Number-2084442: LAT=-2.67 WIND=4.83 HUMIDITY=75 TEMP=81.81 CLOUDINESS=99
# For the city named Victoria, ID Number-1733782: LAT=5.28 WIND=3.36 HUMIDITY=83 TEMP=82.4 CLOUDINESS=75
# For the city named Rikitea, ID Number-4030556: LAT=-23.12 WIND=16.96 HUMIDITY=76 TEMP=69.03 CLOUDINESS=100
# For the city named Hithadhoo, ID Number-1282256: LAT=-0.6 WIND=6.96 HUMIDITY=74 TEMP=83.43 CLOUDINESS=99
# For the city named Mangrol, ID Number-1263751: LAT=25.33 WIND=5.41 HUMIDITY=43 TEMP=96.75 CLOUDINESS=100
# For the city named Albany, ID Number-5106834: LAT=42.65 WIND=5.82 HUMIDITY=82 TEMP=68 CLOUDINESS=90
# For the city named Cabo San Lucas, ID Number-3985710: LAT=22.89 WIND=2.91 HUMIDITY=74 TEMP=81 CLOUDINESS=75
# For the city named Cherskiy, ID Number-2126199: LAT=68.75 WIND=5.35 HUMIDITY=87 TEMP=38.25 CLOUDINESS=100
# For the city named Mount Isa, ID Number-2065594: LAT=-20.73 WIND=11.41 HUMIDITY=22 TEMP=64.4 CLOUDINESS=8
# For the city named Usinsk, ID Number-863061: LAT=66 WIND=11.07 HUMIDITY=64 TEMP=71.55 CLOUDINESS=100
# For the city named Bredasdorp, ID Number-1015776: LAT=-34.53 WIND=11.41 HUMIDITY=72 TEMP=59 CLOUDINESS=67
# For the city named Baghmara, ID Number-1274553: LAT=23.8 WIND=6.85 HUMIDITY=79 TEMP=81.63 CLOUDINESS=100
# For the city named Salisbury, ID Number-2638664: LAT=51.07 WIND=16.11 HUMIDITY=31 TEMP=91 CLOUDINESS=0
# For the city named Nikolskoye, ID Number-546105: LAT=59.7 WIND=4.47 HUMIDITY=38 TEMP=75.2 CLOUDINESS=40
# For the city named Aloleng, ID Number-1731298: LAT=16.13 WIND=1.28 HUMIDITY=67 TEMP=84.51 CLOUDINESS=100
# For the city named Rome, ID Number-6539761: LAT=41.89 WIND=9.17 HUMIDITY=32 TEMP=97 CLOUDINESS=0
# For the city named Arraial do Cabo, ID Number-3471451: LAT=-22.97 WIND=23.04 HUMIDITY=65 TEMP=77 CLOUDINESS=0
# For the city named Harper, ID Number-4696310: LAT=30.3 WIND=14.5 HUMIDITY=88 TEMP=78.01 CLOUDINESS=90
# For the city named Cidreira, ID Number-3466165: LAT=-30.17 WIND=2.59 HUMIDITY=81 TEMP=70.11 CLOUDINESS=100
# For the city named Narsaq, ID Number-3421719: LAT=60.91 WIND=4.7 HUMIDITY=81 TEMP=50 CLOUDINESS=75
# For the city named Cape Town, ID Number-3369157: LAT=-33.93 WIND=23.04 HUMIDITY=76 TEMP=59 CLOUDINESS=75
# For the city named Barrow, ID Number-3833859: LAT=-38.31 WIND=12.62 HUMIDITY=29 TEMP=51.39 CLOUDINESS=0
# For the city named Kahului, ID Number-5847411: LAT=20.89 WIND=19.64 HUMIDITY=69 TEMP=77 CLOUDINESS=75
# For the city named Yako, ID Number-2353688: LAT=12.96 WIND=6.33 HUMIDITY=35 TEMP=94.77 CLOUDINESS=16
# For the city named Antofagasta, ID Number-3899539: LAT=-23.65 WIND=14.99 HUMIDITY=82 TEMP=55.4 CLOUDINESS=75
# For the city named Itarema, ID Number-3393692: LAT=-2.92 WIND=11.5 HUMIDITY=53 TEMP=86.49 CLOUDINESS=49
# For the city named Lima, ID Number-3936456: LAT=-12.06 WIND=5.82 HUMIDITY=87 TEMP=60.8 CLOUDINESS=90
# For the city named Khandyga, ID Number-2022773: LAT=62.65 WIND=2.75 HUMIDITY=42 TEMP=51.39 CLOUDINESS=0
# For the city named Nabire, ID Number-1634614: LAT=-3.36 WIND=1.95 HUMIDITY=99 TEMP=68.49 CLOUDINESS=100
# For the city named Ust-Nera, ID Number-2120048: LAT=64.57 WIND=3.8 HUMIDITY=54 TEMP=40.77 CLOUDINESS=20
# For the city named Bluff, ID Number-2175403: LAT=-23.58 WIND=6.22 HUMIDITY=64 TEMP=58.95 CLOUDINESS=0
# For the city named Faanui, ID Number-4034551: LAT=-16.48 WIND=14.27 HUMIDITY=84 TEMP=79.47 CLOUDINESS=94
# For the city named Atuona, ID Number-4020109: LAT=-9.8 WIND=16.17 HUMIDITY=76 TEMP=79.83 CLOUDINESS=8
# For the city named Punta Arenas, ID Number-3874787: LAT=-53.16 WIND=9.17 HUMIDITY=66 TEMP=33.01 CLOUDINESS=0
# For the city named Zaysan, ID Number-1517060: LAT=47.47 WIND=5.1 HUMIDITY=58 TEMP=64.17 CLOUDINESS=68
# For the city named Palmerston, ID Number-6301965: LAT=-12.49 WIND=8.52 HUMIDITY=82 TEMP=70 CLOUDINESS=0
# For the city named Saldanha, ID Number-2737599: LAT=41.42 WIND=6.82 HUMIDITY=24 TEMP=94.59 CLOUDINESS=13
# For the city named Tual, ID Number-1623197: LAT=-5.67 WIND=16.35 HUMIDITY=84 TEMP=77.13 CLOUDINESS=99
# For the city named Santa Quiteria do Maranhao, ID Number-3389358: LAT=-3.52 WIND=8.72 HUMIDITY=59 TEMP=84.87 CLOUDINESS=86
# For the city named Erzin, ID Number-296852: LAT=36.95 WIND=21.92 HUMIDITY=46 TEMP=93.2 CLOUDINESS=0
# For the city named Banda Aceh, ID Number-1215502: LAT=5.56 WIND=9.1 HUMIDITY=74 TEMP=84.15 CLOUDINESS=100
# For the city named Phangnga, ID Number-1151464: LAT=8.45 WIND=1.5 HUMIDITY=88 TEMP=78.8 CLOUDINESS=20
# For the city named Hilo, ID Number-5855927: LAT=19.71 WIND=6.93 HUMIDITY=88 TEMP=71.6 CLOUDINESS=75
# For the city named Filingue, ID Number-2444995: LAT=14.35 WIND=2.86 HUMIDITY=31 TEMP=95.67 CLOUDINESS=13
# For the city named Kamenka, ID Number-618453: LAT=48.03 WIND=4 HUMIDITY=79 TEMP=68 CLOUDINESS=67
# For the city named Kapaa, ID Number-5848280: LAT=22.08 WIND=10.29 HUMIDITY=78 TEMP=80.6 CLOUDINESS=90
# For the city named Chapais, ID Number-5919850: LAT=49.78 WIND=10.29 HUMIDITY=81 TEMP=46.4 CLOUDINESS=90
# For the city named Beloha, ID Number-1067565: LAT=-25.17 WIND=7.43 HUMIDITY=43 TEMP=65.79 CLOUDINESS=0
# For the city named Loei, ID Number-1609071: LAT=17.49 WIND=1.95 HUMIDITY=88 TEMP=73.35 CLOUDINESS=100
# For the city named Ushuaia, ID Number-3833367: LAT=-54.81 WIND=20.8 HUMIDITY=80 TEMP=33.8 CLOUDINESS=75
# For the city named Wonthaggi, ID Number-2154826: LAT=-38.6 WIND=5.01 HUMIDITY=86 TEMP=48.99 CLOUDINESS=99
# For the city named Biak, ID Number-1637001: LAT=-0.91 WIND=6.53 HUMIDITY=96 TEMP=59.85 CLOUDINESS=100
# For the city named Port Blair, ID Number-1259385: LAT=11.67 WIND=5.82 HUMIDITY=83 TEMP=82.4 CLOUDINESS=40
# For the city named Kodiak, ID Number-4407665: LAT=39.95 WIND=8.05 HUMIDITY=72 TEMP=70 CLOUDINESS=1
# For the city named Guerrero Negro, ID Number-4021858: LAT=27.97 WIND=7.14 HUMIDITY=77 TEMP=68.31 CLOUDINESS=33
# For the city named Tasiilaq, ID Number-3424607: LAT=65.61 WIND=23.04 HUMIDITY=75 TEMP=46.4 CLOUDINESS=40
# For the city named Clarksburg, ID Number-4351708: LAT=39.24 WIND=11.41 HUMIDITY=83 TEMP=70 CLOUDINESS=90
# For the city named Grand Gaube, ID Number-934479: LAT=-20.01 WIND=14.99 HUMIDITY=73 TEMP=73.4 CLOUDINESS=40
# For the city named Kjollefjord, ID Number-779261: LAT=70.95 WIND=4.7 HUMIDITY=64 TEMP=68 CLOUDINESS=0
# For the city named Pangody, ID Number-1495626: LAT=65.85 WIND=16.26 HUMIDITY=58 TEMP=62.55 CLOUDINESS=63
# For the city named Bethel, ID Number-5880568: LAT=60.79 WIND=3.36 HUMIDITY=93 TEMP=55.4 CLOUDINESS=90
# For the city named Hasaki, ID Number-2112802: LAT=35.73 WIND=4.7 HUMIDITY=94 TEMP=75.2 CLOUDINESS=75
# For the city named Lompoc, ID Number-5367788: LAT=34.64 WIND=3.36 HUMIDITY=100 TEMP=59 CLOUDINESS=90
# For the city named Amahai, ID Number-1651591: LAT=-3.31 WIND=10.71 HUMIDITY=89 TEMP=79 CLOUDINESS=100
# For the city named Axim, ID Number-2303611: LAT=4.87 WIND=13.94 HUMIDITY=80 TEMP=77.85 CLOUDINESS=12
# For the city named Taoudenni, ID Number-2450173: LAT=22.68 WIND=4.68 HUMIDITY=9 TEMP=114.03 CLOUDINESS=0
# For the city named Buala, ID Number-2109528: LAT=-8.15 WIND=17.29 HUMIDITY=85 TEMP=78.75 CLOUDINESS=96
# For the city named Astana, ID Number-1526273: LAT=51.13 WIND=8.95 HUMIDITY=88 TEMP=62.6 CLOUDINESS=90
# For the city named Manono, ID Number-209598: LAT=-7.3 WIND=6.55 HUMIDITY=15 TEMP=90.09 CLOUDINESS=1
# For the city named Merauke, ID Number-2082539: LAT=-8.49 WIND=23.35 HUMIDITY=84 TEMP=77.67 CLOUDINESS=11
# For the city named Ribeira Grande, ID Number-3372707: LAT=38.52 WIND=14.99 HUMIDITY=78 TEMP=75.2 CLOUDINESS=75
# For the city named Kathu, ID Number-991664: LAT=-27.7 WIND=5.99 HUMIDITY=15 TEMP=72 CLOUDINESS=0
# For the city named Cabatuan, ID Number-1721714: LAT=16.95 WIND=3.87 HUMIDITY=88 TEMP=76.95 CLOUDINESS=100
# For the city named Vao, ID Number-588365: LAT=59.1 WIND=5.12 HUMIDITY=47 TEMP=72.99 CLOUDINESS=0
# For the city named Mataura, ID Number-6201424: LAT=-46.19 WIND=1.99 HUMIDITY=97 TEMP=41 CLOUDINESS=3
# For the city named Norman Wells, ID Number-6089245: LAT=65.28 WIND=5.82 HUMIDITY=82 TEMP=57.2 CLOUDINESS=40
# For the city named Chokurdakh, ID Number-2126123: LAT=70.62 WIND=14.18 HUMIDITY=64 TEMP=47.97 CLOUDINESS=100
# For the city named Bagdarin, ID Number-2027244: LAT=54.44 WIND=3.15 HUMIDITY=92 TEMP=50.31 CLOUDINESS=0
# For the city named Pevek, ID Number-2122090: LAT=69.7 WIND=11.79 HUMIDITY=95 TEMP=30.33 CLOUDINESS=100
# For the city named Kavieng, ID Number-2094342: LAT=-2.57 WIND=20.62 HUMIDITY=75 TEMP=83.61 CLOUDINESS=99
# For the city named Winchester, ID Number-2633858: LAT=51.06 WIND=8.05 HUMIDITY=35 TEMP=93 CLOUDINESS=0
# For the city named Katima Mulilo, ID Number-877178: LAT=-17.5 WIND=2.24 HUMIDITY=13 TEMP=78.8 CLOUDINESS=0
# For the city named Upernavik, ID Number-3418910: LAT=72.79 WIND=7.85 HUMIDITY=61 TEMP=47.07 CLOUDINESS=0
# For the city named Ulstrup, ID Number-2820205: LAT=54.81 WIND=12.75 HUMIDITY=61 TEMP=82.99 CLOUDINESS=20
# For the city named Dikson, ID Number-1507390: LAT=73.51 WIND=4.81 HUMIDITY=90 TEMP=35.37 CLOUDINESS=11
# For the city named Kupang, ID Number-2057087: LAT=-10.16 WIND=16.67 HUMIDITY=71 TEMP=74.97 CLOUDINESS=44
# For the city named Suratgarh, ID Number-1255361: LAT=29.32 WIND=6.31 HUMIDITY=29 TEMP=103.41 CLOUDINESS=0
# For the city named Znamenskoye, ID Number-1485020: LAT=57.13 WIND=2.89 HUMIDITY=74 TEMP=64.53 CLOUDINESS=0
# For the city named Vaini, ID Number-1273574: LAT=15.34 WIND=6.93 HUMIDITY=94 TEMP=71.6 CLOUDINESS=75
# For the city named Cockburn Town, ID Number-3576994: LAT=21.46 WIND=11.41 HUMIDITY=62 TEMP=89.6 CLOUDINESS=40
# For the city named Navalcarnero, ID Number-3115659: LAT=40.29 WIND=11.41 HUMIDITY=14 TEMP=100 CLOUDINESS=0
# For the city named Hermanus, ID Number-3366880: LAT=-34.42 WIND=8.99 HUMIDITY=67 TEMP=57.99 CLOUDINESS=67
# For the city named Takoradi, ID Number-2294915: LAT=4.89 WIND=10.47 HUMIDITY=67 TEMP=81.63 CLOUDINESS=84
# For the city named Pozoblanco, ID Number-2512340: LAT=38.38 WIND=8.05 HUMIDITY=25 TEMP=100.4 CLOUDINESS=0
# For the city named Jawhar, ID Number-1269106: LAT=19.91 WIND=8.86 HUMIDITY=88 TEMP=80.91 CLOUDINESS=46
# For the city named Isla Vista, ID Number-5359864: LAT=34.41 WIND=3.36 HUMIDITY=100 TEMP=62.6 CLOUDINESS=90
# For the city named Provideniya, ID Number-4031574: LAT=64.42 WIND=3.49 HUMIDITY=96 TEMP=44.37 CLOUDINESS=100
# For the city named La Uvita, ID Number-3676884: LAT=6.32 WIND=2.53 HUMIDITY=60 TEMP=71.37 CLOUDINESS=100
# For the city named Inhambane, ID Number-1045114: LAT=-23.87 WIND=18.34 HUMIDITY=50 TEMP=75.2 CLOUDINESS=20
# For the city named Qaanaaq, ID Number-3831208: LAT=77.48 WIND=9.1 HUMIDITY=64 TEMP=41.49 CLOUDINESS=100
# For the city named Anadyr, ID Number-2127202: LAT=64.73 WIND=6.71 HUMIDITY=81 TEMP=44.6 CLOUDINESS=0
# For the city named Nome, ID Number-4732862: LAT=30.04 WIND=5.82 HUMIDITY=83 TEMP=80.6 CLOUDINESS=40
# For the city named Kushiro, ID Number-2129072: LAT=43.11 WIND=3.38 HUMIDITY=98 TEMP=58.77 CLOUDINESS=100
# For the city named Vardo, ID Number-4372777: LAT=39.62 WIND=3.36 HUMIDITY=83 TEMP=71.6 CLOUDINESS=1
# For the city named Terrace, ID Number-6162949: LAT=54.52 WIND=5.82 HUMIDITY=93 TEMP=55.4 CLOUDINESS=75
# For the city named Almaznyy, ID Number-582447: LAT=48.03 WIND=11.18 HUMIDITY=29 TEMP=89.6 CLOUDINESS=20
# For the city named Saint-Louis, ID Number-2246452: LAT=16.03 WIND=4.7 HUMIDITY=62 TEMP=87.8 CLOUDINESS=0
# For the city named Prince George, ID Number-6113365: LAT=53.92 WIND=6.93 HUMIDITY=93 TEMP=57 CLOUDINESS=20
# For the city named Joniskis, ID Number-598796: LAT=56.24 WIND=9.17 HUMIDITY=53 TEMP=73.4 CLOUDINESS=75
# For the city named Airai, ID Number-1651810: LAT=-8.93 WIND=6.13 HUMIDITY=66 TEMP=65.61 CLOUDINESS=0
# For the city named Karratha, ID Number-6620339: LAT=-20.74 WIND=10.8 HUMIDITY=66 TEMP=63.99 CLOUDINESS=84
# For the city named Morondava, ID Number-1058381: LAT=-20.3 WIND=11.45 HUMIDITY=53 TEMP=74.25 CLOUDINESS=0
# For the city named Castro, ID Number-3896218: LAT=-42.48 WIND=1.12 HUMIDITY=100 TEMP=33.8 CLOUDINESS=75
# For the city named Lagoa, ID Number-2267254: LAT=37.14 WIND=9.17 HUMIDITY=74 TEMP=84.99 CLOUDINESS=40
# For the city named Mahebourg, ID Number-934322: LAT=-20.41 WIND=14.99 HUMIDITY=73 TEMP=73.4 CLOUDINESS=40
# For the city named Makakilo City, ID Number-5850554: LAT=21.35 WIND=10.27 HUMIDITY=78 TEMP=80.6 CLOUDINESS=90
# For the city named Innisfail, ID Number-2162683: LAT=-17.52 WIND=5.82 HUMIDITY=91 TEMP=66.51 CLOUDINESS=97
# For the city named San Jeronimo, ID Number-3929607: LAT=-13.65 WIND=4.25 HUMIDITY=60 TEMP=42.8 CLOUDINESS=90
# For the city named Saint-Pierre, ID Number-2995603: LAT=48.95 WIND=5.82 HUMIDITY=17 TEMP=100 CLOUDINESS=0
# For the city named Tautira, ID Number-4033557: LAT=-17.73 WIND=13.87 HUMIDITY=83 TEMP=77 CLOUDINESS=96
# For the city named Saint Anthony, ID Number-5606187: LAT=43.97 WIND=4.7 HUMIDITY=46 TEMP=69.8 CLOUDINESS=1
# For the city named Pandharpur, ID Number-1260546: LAT=17.68 WIND=18.39 HUMIDITY=72 TEMP=78.93 CLOUDINESS=100
# For the city named La Rioja, ID Number-3848950: LAT=-29.41 WIND=6.26 HUMIDITY=32 TEMP=42.93 CLOUDINESS=0
# For the city named Geraldton, ID Number-5960603: LAT=49.72 WIND=4.7 HUMIDITY=82 TEMP=59 CLOUDINESS=20
# For the city named Burnie, ID Number-2173125: LAT=-41.05 WIND=1.99 HUMIDITY=92 TEMP=39 CLOUDINESS=4
# For the city named Luchow, ID Number-2875542: LAT=52.97 WIND=6.93 HUMIDITY=37 TEMP=87.01 CLOUDINESS=20
# For the city named Hobyo, ID Number-57000: LAT=5.35 WIND=29.42 HUMIDITY=61 TEMP=80.19 CLOUDINESS=65
# For the city named Ravar, ID Number-118704: LAT=31.27 WIND=12.37 HUMIDITY=3 TEMP=85.77 CLOUDINESS=27
# For the city named Ilulissat, ID Number-3423146: LAT=69.22 WIND=3.36 HUMIDITY=43 TEMP=55.4 CLOUDINESS=40
# For the city named Chumikan, ID Number-2025256: LAT=54.72 WIND=3.09 HUMIDITY=94 TEMP=46.35 CLOUDINESS=100
# For the city named Ust-Omchug, ID Number-2120047: LAT=61.13 WIND=1.19 HUMIDITY=75 TEMP=30.51 CLOUDINESS=0
# For the city named Arlit, ID Number-2447513: LAT=18.74 WIND=4.54 HUMIDITY=19 TEMP=103.59 CLOUDINESS=0
# For the city named Qorveh, ID Number-119161: LAT=35.17 WIND=11.54 HUMIDITY=18 TEMP=86.49 CLOUDINESS=82
# For the city named Vuktyl, ID Number-470905: LAT=63.86 WIND=8.19 HUMIDITY=61 TEMP=71.01 CLOUDINESS=55
# For the city named Tiarei, ID Number-4033356: LAT=-17.53 WIND=13.87 HUMIDITY=83 TEMP=77 CLOUDINESS=66
# For the city named Adrar, ID Number-2508813: LAT=27.87 WIND=17.22 HUMIDITY=9 TEMP=111.2 CLOUDINESS=0
# For the city named Ouegoa, ID Number-2139259: LAT=-20.34 WIND=10.71 HUMIDITY=69 TEMP=69.03 CLOUDINESS=5
# For the city named Zhigansk, ID Number-2012530: LAT=66.77 WIND=8.28 HUMIDITY=37 TEMP=60.93 CLOUDINESS=0
# For the city named Olenegorsk, ID Number-515698: LAT=68.14 WIND=5.77 HUMIDITY=46 TEMP=76.23 CLOUDINESS=100
# For the city named Mwinilunga, ID Number-902620: LAT=-11.73 WIND=5.95 HUMIDITY=17 TEMP=78.03 CLOUDINESS=0
# For the city named Valls, ID Number-3106492: LAT=41.28 WIND=11.41 HUMIDITY=41 TEMP=105.01 CLOUDINESS=20
# For the city named Aklavik, ID Number-5882953: LAT=68.22 WIND=3.36 HUMIDITY=93 TEMP=59 CLOUDINESS=75
# For the city named Labuhan, ID Number-1641899: LAT=-2.54 WIND=2.75 HUMIDITY=85 TEMP=72.63 CLOUDINESS=86
# For the city named East London, ID Number-1006984: LAT=-33.02 WIND=14.99 HUMIDITY=14 TEMP=87.8 CLOUDINESS=0
# For the city named Atar, ID Number-2381334: LAT=20.52 WIND=8.39 HUMIDITY=12 TEMP=109.53 CLOUDINESS=0
# For the city named Goderich, ID Number-5962442: LAT=43.74 WIND=17.27 HUMIDITY=78 TEMP=69.01 CLOUDINESS=0
# For the city named Sabaudia, ID Number-3168764: LAT=41.3 WIND=9.17 HUMIDITY=32 TEMP=98.6 CLOUDINESS=0
# For the city named Plettenberg Bay, ID Number-964712: LAT=-34.05 WIND=13.67 HUMIDITY=80 TEMP=52.11 CLOUDINESS=37
# For the city named Sale, ID Number-2150615: LAT=-38.11 WIND=10.89 HUMIDITY=84 TEMP=48.99 CLOUDINESS=52
# For the city named Ponta do Sol, ID Number-3453439: LAT=-20.63 WIND=6.78 HUMIDITY=56 TEMP=69.75 CLOUDINESS=83
# For the city named Yaan, ID Number-2338660: LAT=7.38 WIND=5.5 HUMIDITY=84 TEMP=81.63 CLOUDINESS=71
# For the city named Te Anau, ID Number-2181625: LAT=-45.41 WIND=0.87 HUMIDITY=81 TEMP=41.85 CLOUDINESS=0
# For the city named Paramonga, ID Number-3933024: LAT=-10.68 WIND=14.58 HUMIDITY=89 TEMP=61.11 CLOUDINESS=100
# For the city named Moose Factory, ID Number-6078372: LAT=51.26 WIND=4.7 HUMIDITY=75 TEMP=46.4 CLOUDINESS=40
# For the city named Uyovu, ID Number-149027: LAT=-3.28 WIND=7.49 HUMIDITY=23 TEMP=82.17 CLOUDINESS=13
# For the city named Abu Dhabi, ID Number-292968: LAT=24.47 WIND=10.29 HUMIDITY=56 TEMP=104 CLOUDINESS=13
# For the city named Chuy, ID Number-3443061: LAT=-33.69 WIND=13.53 HUMIDITY=79 TEMP=56.97 CLOUDINESS=100
# For the city named Constitucion, ID Number-4011743: LAT=23.99 WIND=14 HUMIDITY=87 TEMP=64 CLOUDINESS=20
# For the city named Graham, ID Number-4694420: LAT=33.11 WIND=3.36 HUMIDITY=78 TEMP=78.01 CLOUDINESS=1
# For the city named Dillon, ID Number-5648657: LAT=45.22 WIND=4.7 HUMIDITY=77 TEMP=64.99 CLOUDINESS=1
# For the city named Kaitangata, ID Number-2208248: LAT=-46.28 WIND=1.99 HUMIDITY=86 TEMP=44.01 CLOUDINESS=3
# For the city named Xingyi, ID Number-1787599: LAT=24.19 WIND=3.18 HUMIDITY=99 TEMP=61.47 CLOUDINESS=100
# For the city named Bubaque, ID Number-2374583: LAT=11.28 WIND=10.22 HUMIDITY=80 TEMP=79.83 CLOUDINESS=85
# For the city named Huarmey, ID Number-3939168: LAT=-10.07 WIND=15.82 HUMIDITY=85 TEMP=62.55 CLOUDINESS=100
# For the city named Noyabrsk, ID Number-1496503: LAT=63.2 WIND=15.52 HUMIDITY=60 TEMP=69.21 CLOUDINESS=89
# For the city named Luderitz, ID Number-3355672: LAT=-26.65 WIND=18.34 HUMIDITY=72 TEMP=64.4 CLOUDINESS=91
# For the city named Yermekeyevo, ID Number-467260: LAT=54.07 WIND=6.51 HUMIDITY=82 TEMP=66.33 CLOUDINESS=0
# For the city named Mandalgovi, ID Number-2030065: LAT=45.76 WIND=7.54 HUMIDITY=73 TEMP=62.19 CLOUDINESS=1
# For the city named Puerto Colombia, ID Number-3671497: LAT=10.99 WIND=9.17 HUMIDITY=94 TEMP=78.8 CLOUDINESS=75
# For the city named Longyearbyen, ID Number-2729907: LAT=78.22 WIND=5.82 HUMIDITY=70 TEMP=48.2 CLOUDINESS=75
# For the city named Sabya, ID Number-102651: LAT=17.15 WIND=20.8 HUMIDITY=59 TEMP=95 CLOUDINESS=40
# For the city named Saint-Philippe, ID Number-6138908: LAT=45.36 WIND=7.31 HUMIDITY=64 TEMP=73.99 CLOUDINESS=1
# For the city named Tiksi, ID Number-2015306: LAT=71.64 WIND=11.65 HUMIDITY=83 TEMP=41.31 CLOUDINESS=100
# For the city named Nanortalik, ID Number-3421765: LAT=60.14 WIND=5.84 HUMIDITY=93 TEMP=39.33 CLOUDINESS=100
# For the city named Gushikawa, ID Number-1863495: LAT=26.35 WIND=4.7 HUMIDITY=78 TEMP=82.4 CLOUDINESS=75
# For the city named Kununurra, ID Number-2068110: LAT=-15.77 WIND=7.56 HUMIDITY=59 TEMP=62.6 CLOUDINESS=2
# For the city named Sibolga, ID Number-1213855: LAT=1.74 WIND=2.51 HUMIDITY=70 TEMP=83.43 CLOUDINESS=100
# For the city named Quelimane, ID Number-1028434: LAT=-17.88 WIND=3.36 HUMIDITY=47 TEMP=77 CLOUDINESS=40
# For the city named Khasan, ID Number-2039557: LAT=42.43 WIND=2.04 HUMIDITY=97 TEMP=69.57 CLOUDINESS=100
# For the city named Brae, ID Number-2654970: LAT=60.4 WIND=12.75 HUMIDITY=82 TEMP=68 CLOUDINESS=75
# For the city named Kurumkan, ID Number-2021188: LAT=54.33 WIND=6.78 HUMIDITY=71 TEMP=56.43 CLOUDINESS=100
# For the city named Benguela, ID Number-3351663: LAT=-12.58 WIND=6.93 HUMIDITY=73 TEMP=75.2 CLOUDINESS=75
# For the city named Visnes, ID Number-3131500: LAT=59.36 WIND=12.75 HUMIDITY=77 TEMP=71.6 CLOUDINESS=20
# For the city named Pontianak, ID Number-1630789: LAT=-0.02 WIND=12.53 HUMIDITY=78 TEMP=81.81 CLOUDINESS=100
# For the city named Vila Velha, ID Number-6320062: LAT=-3.71 WIND=12.75 HUMIDITY=74 TEMP=80.6 CLOUDINESS=75
# For the city named Aswan, ID Number-359792: LAT=24.09 WIND=13.91 HUMIDITY=9 TEMP=102.51 CLOUDINESS=0
# For the city named Ayan, ID Number-117656: LAT=38.23 WIND=13.13 HUMIDITY=19 TEMP=80.01 CLOUDINESS=71
# For the city named Marsa Matruh, ID Number-352733: LAT=31.35 WIND=13.87 HUMIDITY=62 TEMP=86 CLOUDINESS=0
# For the city named Malkangiri, ID Number-1264075: LAT=18.35 WIND=5.03 HUMIDITY=86 TEMP=79.47 CLOUDINESS=67
# For the city named Tromso, ID Number-3133895: LAT=69.65 WIND=11.41 HUMIDITY=68 TEMP=73.4 CLOUDINESS=40
# For the city named San Cristobal, ID Number-3609418: LAT=14.68 WIND=2.93 HUMIDITY=53 TEMP=79.65 CLOUDINESS=100
# For the city named Gariaband, ID Number-1271534: LAT=20.63 WIND=3.15 HUMIDITY=81 TEMP=78.93 CLOUDINESS=87
# For the city named Klaksvik, ID Number-2618795: LAT=62.23 WIND=11.41 HUMIDITY=93 TEMP=55.4 CLOUDINESS=100
# For the city named Bollnas, ID Number-2720679: LAT=61.35 WIND=4.61 HUMIDITY=52 TEMP=74.43 CLOUDINESS=58
# For the city named Russell, ID Number-4278471: LAT=38.9 WIND=3.36 HUMIDITY=82 TEMP=72 CLOUDINESS=1
# For the city named Bambous Virieux, ID Number-1106677: LAT=-20.34 WIND=14.99 HUMIDITY=73 TEMP=73.4 CLOUDINESS=40
# For the city named Bettiah, ID Number-1276393: LAT=26.8 WIND=6.69 HUMIDITY=76 TEMP=85.77 CLOUDINESS=99
# For the city named Sapouy, ID Number-2355869: LAT=11.55 WIND=5.1 HUMIDITY=60 TEMP=83.25 CLOUDINESS=51
# For the city named Dubrovnik, ID Number-3201047: LAT=42.65 WIND=8.05 HUMIDITY=33 TEMP=91.4 CLOUDINESS=20
# For the city named Saint George, ID Number-262462: LAT=39.45 WIND=5.82 HUMIDITY=43 TEMP=91 CLOUDINESS=40
# For the city named Coquimbo, ID Number-3893629: LAT=-29.95 WIND=8.05 HUMIDITY=75 TEMP=46.4 CLOUDINESS=0
# For the city named Ishigaki, ID Number-1861416: LAT=24.34 WIND=10.25 HUMIDITY=77 TEMP=83.43 CLOUDINESS=94
# For the city named Akureyri, ID Number-2633274: LAT=65.68 WIND=8.05 HUMIDITY=76 TEMP=53.6 CLOUDINESS=90
# For the city named Seymchan, ID Number-2121373: LAT=62.93 WIND=1.97 HUMIDITY=85 TEMP=26.91 CLOUDINESS=4
# For the city named Raymond, ID Number-6117675: LAT=49.47 WIND=4.7 HUMIDITY=87 TEMP=60.8 CLOUDINESS=75
# For the city named Bam, ID Number-141736: LAT=29.11 WIND=9.1 HUMIDITY=13 TEMP=79.47 CLOUDINESS=2
# For the city named Deep River, ID Number-5937073: LAT=46.1 WIND=8.05 HUMIDITY=63 TEMP=69.01 CLOUDINESS=20
# For the city named Calvinia, ID Number-3369174: LAT=-31.47 WIND=31.45 HUMIDITY=77 TEMP=44.91 CLOUDINESS=100
# For the city named Boysun, ID Number-1217734: LAT=38.2 WIND=4.68 HUMIDITY=23 TEMP=73.71 CLOUDINESS=0
# For the city named Saskylakh, ID Number-2017155: LAT=71.97 WIND=6.15 HUMIDITY=70 TEMP=50.67 CLOUDINESS=94
# For the city named College, ID Number-5859699: LAT=64.86 WIND=1.48 HUMIDITY=82 TEMP=63 CLOUDINESS=1
# For the city named Carnarvon, ID Number-1014034: LAT=-30.97 WIND=42.5 HUMIDITY=64 TEMP=48.33 CLOUDINESS=67
# For the city named Bahia Honda, ID Number-3567995: LAT=22.9 WIND=3.11 HUMIDITY=69 TEMP=82.35 CLOUDINESS=0
# For the city named Dubbo, ID Number-2168305: LAT=-32.25 WIND=1.12 HUMIDITY=39 TEMP=48.2 CLOUDINESS=0
# For the city named Manjacaze, ID Number-1040938: LAT=-24.71 WIND=8.7 HUMIDITY=34 TEMP=72.99 CLOUDINESS=0
# For the city named Kruisfontein, ID Number-986717: LAT=-34 WIND=33.4 HUMIDITY=57 TEMP=59.85 CLOUDINESS=16
# For the city named Molchanovo, ID Number-1498493: LAT=57.58 WIND=4.23 HUMIDITY=74 TEMP=59.49 CLOUDINESS=74
# For the city named Padang, ID Number-1633419: LAT=-0.92 WIND=3.49 HUMIDITY=75 TEMP=82.35 CLOUDINESS=100
# For the city named Athabasca, ID Number-5887916: LAT=54.72 WIND=3.85 HUMIDITY=83 TEMP=67.59 CLOUDINESS=0
# For the city named Natitingou, ID Number-2392601: LAT=10.31 WIND=4.7 HUMIDITY=88 TEMP=71.6 CLOUDINESS=75
# For the city named Khatanga, ID Number-2022572: LAT=71.98 WIND=12.03 HUMIDITY=53 TEMP=52.65 CLOUDINESS=100
# For the city named Souillac, ID Number-3026644: LAT=45.6 WIND=12.75 HUMIDITY=26 TEMP=106 CLOUDINESS=0
# For the city named Nishihara, ID Number-1850144: LAT=35.74 WIND=5.82 HUMIDITY=88 TEMP=80.01 CLOUDINESS=75
# For the city named Temirtau, ID Number-1518262: LAT=50.05 WIND=8.95 HUMIDITY=68 TEMP=66.2 CLOUDINESS=40
# For the city named Iqaluit, ID Number-5983720: LAT=63.75 WIND=4.7 HUMIDITY=100 TEMP=39.2 CLOUDINESS=90
# For the city named Mount Gambier, ID Number-2156643: LAT=-37.83 WIND=9.17 HUMIDITY=81 TEMP=46.4 CLOUDINESS=90
# For the city named Vyartsilya, ID Number-470762: LAT=62.18 WIND=4.25 HUMIDITY=47 TEMP=72.27 CLOUDINESS=100
# For the city named Ubauro, ID Number-1163021: LAT=28.16 WIND=6.76 HUMIDITY=24 TEMP=106.83 CLOUDINESS=94
# For the city named Olinda, ID Number-2154386: LAT=-37.84 WIND=12.75 HUMIDITY=75 TEMP=50 CLOUDINESS=40
# For the city named Aykhal, ID Number-2027296: LAT=65.95 WIND=2.24 HUMIDITY=29 TEMP=75.2 CLOUDINESS=93
# For the city named Yarmouth, ID Number-6185217: LAT=43.84 WIND=10.29 HUMIDITY=100 TEMP=68 CLOUDINESS=90
# For the city named Tsogni, ID Number-2400547: LAT=-2.79 WIND=15.52 HUMIDITY=88 TEMP=72.27 CLOUDINESS=0
# For the city named Porbandar, ID Number-1259395: LAT=21.64 WIND=17.47 HUMIDITY=84 TEMP=84.51 CLOUDINESS=100
# For the city named Ratnagiri, ID Number-1258338: LAT=16.98 WIND=15.84 HUMIDITY=85 TEMP=80.73 CLOUDINESS=63
# For the city named Cleburne, ID Number-4681976: LAT=32.35 WIND=12.75 HUMIDITY=65 TEMP=79 CLOUDINESS=1
# For the city named Hokitika, ID Number-2206894: LAT=-42.72 WIND=4.27 HUMIDITY=63 TEMP=47.43 CLOUDINESS=0
# For the city named Ystad, ID Number-2662149: LAT=55.43 WIND=14.99 HUMIDITY=61 TEMP=81 CLOUDINESS=40
# For the city named Quetigny, ID Number-2984775: LAT=47.31 WIND=4.7 HUMIDITY=22 TEMP=102.99 CLOUDINESS=0
# For the city named Storslett, ID Number-777381: LAT=69.77 WIND=1.12 HUMIDITY=77 TEMP=66.2 CLOUDINESS=0
# For the city named Nemuro, ID Number-2128975: LAT=43.32 WIND=13.85 HUMIDITY=87 TEMP=59.31 CLOUDINESS=77
# For the city named Tazovskiy, ID Number-1489853: LAT=67.47 WIND=17.83 HUMIDITY=68 TEMP=55.35 CLOUDINESS=2
# For the city named Praia da Vitoria, ID Number-3372760: LAT=38.73 WIND=17.9 HUMIDITY=65 TEMP=78.8 CLOUDINESS=20
# For the city named Sarti, ID Number-734339: LAT=40.1 WIND=1.5 HUMIDITY=47 TEMP=86.31 CLOUDINESS=24
# For the city named Khuzdar, ID Number-7082481: LAT=27.8 WIND=17.83 HUMIDITY=54 TEMP=79.47 CLOUDINESS=80
# For the city named Nikolayevsk-na-amure, ID Number-2122850: LAT=53.14 WIND=14.92 HUMIDITY=98 TEMP=49.95 CLOUDINESS=100
# For the city named Nizwa, ID Number-286987: LAT=22.93 WIND=11.5 HUMIDITY=39 TEMP=90.45 CLOUDINESS=18
# For the city named Kokemaki, ID Number-651980: LAT=61.26 WIND=9.17 HUMIDITY=60 TEMP=79 CLOUDINESS=0
# For the city named Batagay-Alyta, ID Number-2027042: LAT=67.8 WIND=4.74 HUMIDITY=47 TEMP=49.95 CLOUDINESS=33
# For the city named Westport, ID Number-4845585: LAT=41.14 WIND=5.82 HUMIDITY=88 TEMP=68 CLOUDINESS=90
# For the city named Waitara, ID Number-2208091: LAT=-39 WIND=3.51 HUMIDITY=76 TEMP=52.29 CLOUDINESS=100
# For the city named Saint-Raymond, ID Number-6639619: LAT=46.89 WIND=6.06 HUMIDITY=82 TEMP=69.01 CLOUDINESS=75
# For the city named Port Hedland, ID Number-2063042: LAT=-20.31 WIND=8.05 HUMIDITY=48 TEMP=66.2 CLOUDINESS=91
# For the city named Ongandjera, ID Number-3354178: LAT=-17.88 WIND=3.31 HUMIDITY=9 TEMP=82.17 CLOUDINESS=0
# For the city named Sabang, ID Number-1726279: LAT=13.8 WIND=1.99 HUMIDITY=90 TEMP=80.01 CLOUDINESS=15
# For the city named Romitan, ID Number-1217662: LAT=39.93 WIND=11.41 HUMIDITY=16 TEMP=102.2 CLOUDINESS=0
# For the city named Grand Forks, ID Number-5059429: LAT=47.91 WIND=3.22 HUMIDITY=64 TEMP=71.6 CLOUDINESS=1
# For the city named Skjervoy, ID Number-777682: LAT=70.03 WIND=1.12 HUMIDITY=77 TEMP=66.2 CLOUDINESS=0
# For the city named Talnakh, ID Number-1490256: LAT=69.49 WIND=20.13 HUMIDITY=77 TEMP=60.8 CLOUDINESS=0
# For the city named San Lorenzo, ID Number-3601977: LAT=13.43 WIND=1.14 HUMIDITY=66 TEMP=84.2 CLOUDINESS=0
# For the city named Salalah, ID Number-286621: LAT=17.01 WIND=13.87 HUMIDITY=88 TEMP=82.4 CLOUDINESS=75
# For the city named Gondar, ID Number-2736041: LAT=41.82 WIND=8.05 HUMIDITY=88 TEMP=86 CLOUDINESS=75
# For the city named Bima, ID Number-1648759: LAT=-8.45 WIND=1.88 HUMIDITY=95 TEMP=63.81 CLOUDINESS=57
# For the city named Comodoro Rivadavia, ID Number-3860443: LAT=-45.87 WIND=14.99 HUMIDITY=52 TEMP=44.6 CLOUDINESS=0
# For the city named Coihaique, ID Number-3894426: LAT=-45.58 WIND=4.7 HUMIDITY=86 TEMP=37.4 CLOUDINESS=40
# For the city named Batemans Bay, ID Number-2176639: LAT=-35.71 WIND=5.99 HUMIDITY=72 TEMP=60.01 CLOUDINESS=89
# For the city named Petropavlovskoye, ID Number-2127154: LAT=46.79 WIND=4.47 HUMIDITY=93 TEMP=66.2 CLOUDINESS=75
# For the city named Del Rio, ID Number-5520076: LAT=29.36 WIND=8.05 HUMIDITY=58 TEMP=86 CLOUDINESS=1
# For the city named Calgary, ID Number-5913490: LAT=51.05 WIND=3.36 HUMIDITY=77 TEMP=68 CLOUDINESS=40
# For the city named Pucallpa, ID Number-3693345: LAT=-8.38 WIND=1.72 HUMIDITY=331 TEMP=35.6 CLOUDINESS=40
# For the city named Rongcheng, ID Number-1786855: LAT=37.16 WIND=12.26 HUMIDITY=93 TEMP=76.95 CLOUDINESS=100
# For the city named Havre-Saint-Pierre, ID Number-5972291: LAT=50.23 WIND=9.17 HUMIDITY=68 TEMP=64.4 CLOUDINESS=1
# For the city named Teeli, ID Number-1489828: LAT=51.01 WIND=4.09 HUMIDITY=75 TEMP=57.69 CLOUDINESS=100
# For the city named Bayan, ID Number-1813029: LAT=36.1 WIND=4.92 HUMIDITY=85 TEMP=53.01 CLOUDINESS=100
# For the city named Gubkinskiy, ID Number-1539209: LAT=64.43 WIND=14.12 HUMIDITY=60 TEMP=68.67 CLOUDINESS=33
# For the city named Ballangen, ID Number-3162108: LAT=68.34 WIND=10.29 HUMIDITY=47 TEMP=77 CLOUDINESS=0
# For the city named Zhangye, ID Number-1785036: LAT=38.94 WIND=8.88 HUMIDITY=41 TEMP=66.15 CLOUDINESS=67
# For the city named Mitu, ID Number-117392: LAT=36.2 WIND=12.84 HUMIDITY=13 TEMP=92.97 CLOUDINESS=51
# For the city named Chitipa, ID Number-235751: LAT=-9.7 WIND=8.34 HUMIDITY=42 TEMP=67.05 CLOUDINESS=50
# For the city named San Rafael, ID Number-3836669: LAT=-34.61 WIND=1.1 HUMIDITY=35 TEMP=44.01 CLOUDINESS=0
# For the city named Casian, ID Number-673382: LAT=44.5 WIND=11.41 HUMIDITY=61 TEMP=82.4 CLOUDINESS=40
# For the city named Yerbogachen, ID Number-2012956: LAT=61.28 WIND=9.33 HUMIDITY=50 TEMP=66.51 CLOUDINESS=100
# For the city named Shangzhi, ID Number-2035002: LAT=45.21 WIND=3.13 HUMIDITY=93 TEMP=66.33 CLOUDINESS=100
# For the city named The Valley, ID Number-3573374: LAT=18.22 WIND=18.34 HUMIDITY=66 TEMP=89.01 CLOUDINESS=20
# For the city named Madimba, ID Number-2221046: LAT=4.42 WIND=3.36 HUMIDITY=74 TEMP=86 CLOUDINESS=75
# For the city named Udachnyy, ID Number-2014624: LAT=66.42 WIND=2.24 HUMIDITY=29 TEMP=75.2 CLOUDINESS=39
# For the city named Haines Junction, ID Number-5969025: LAT=60.75 WIND=7.85 HUMIDITY=97 TEMP=49.95 CLOUDINESS=100
# For the city named Acapulco, ID Number-3533462: LAT=16.86 WIND=6.93 HUMIDITY=88 TEMP=77 CLOUDINESS=90
# For the city named Cotonou, ID Number-2394819: LAT=6.37 WIND=13.87 HUMIDITY=83 TEMP=80.6 CLOUDINESS=20
# For the city named Moerai, ID Number-4034188: LAT=-22.43 WIND=23.8 HUMIDITY=88 TEMP=74.97 CLOUDINESS=97
# For the city named Thunder Bay, ID Number-6166142: LAT=48.41 WIND=4.7 HUMIDITY=88 TEMP=70 CLOUDINESS=40
# For the city named Pathein, ID Number-1328421: LAT=16.78 WIND=5.86 HUMIDITY=87 TEMP=80.73 CLOUDINESS=100
# For the city named Nova Olinda do Norte, ID Number-3393838: LAT=-3.89 WIND=5.48 HUMIDITY=44 TEMP=91.53 CLOUDINESS=8
# For the city named Sulangan, ID Number-1685422: LAT=11.14 WIND=8.05 HUMIDITY=75 TEMP=82.53 CLOUDINESS=86
# For the city named Esperance, ID Number-2071860: LAT=-33.86 WIND=5.82 HUMIDITY=100 TEMP=51.8 CLOUDINESS=90
# For the city named Forestville, ID Number-6944112: LAT=48.74 WIND=5.82 HUMIDITY=52 TEMP=69.8 CLOUDINESS=75
# For the city named Guerrero, ID Number-3836564: LAT=-24.19 WIND=11.41 HUMIDITY=31 TEMP=50 CLOUDINESS=90
# For the city named Sangar, ID Number-2017215: LAT=63.92 WIND=2.24 HUMIDITY=70 TEMP=54.81 CLOUDINESS=0
# For the city named Smithers, ID Number-6149996: LAT=54.78 WIND=2.24 HUMIDITY=100 TEMP=51.8 CLOUDINESS=75
# For the city named Makat, ID Number-608872: LAT=47.65 WIND=12.19 HUMIDITY=19 TEMP=90.63 CLOUDINESS=39
# For the city named Riyadh, ID Number-108410: LAT=24.63 WIND=23.04 HUMIDITY=7 TEMP=109.4 CLOUDINESS=7
# For the city named Dingle, ID Number-1714733: LAT=11 WIND=3.29 HUMIDITY=88 TEMP=75.51 CLOUDINESS=99
# For the city named Ganzhou, ID Number-1810638: LAT=25.86 WIND=2.8 HUMIDITY=92 TEMP=75.51 CLOUDINESS=0
# For the city named Hamilton, ID Number-5969785: LAT=43.26 WIND=6.93 HUMIDITY=77 TEMP=77 CLOUDINESS=20
# For the city named Izumo, ID Number-1861084: LAT=35.37 WIND=5.82 HUMIDITY=88 TEMP=77 CLOUDINESS=40
# For the city named Zigos, ID Number-733749: LAT=41.02 WIND=5.82 HUMIDITY=61 TEMP=78.8 CLOUDINESS=75
# For the city named Finschhafen, ID Number-2097418: LAT=-6.6 WIND=0.81 HUMIDITY=95 TEMP=63.63 CLOUDINESS=91
# For the city named Micheweni, ID Number-153955: LAT=-4.97 WIND=22.93 HUMIDITY=64 TEMP=77.13 CLOUDINESS=34
# For the city named Muros, ID Number-3115824: LAT=42.77 WIND=8.05 HUMIDITY=61 TEMP=82 CLOUDINESS=20
# For the city named Leningradskiy, ID Number-2123814: LAT=69.38 WIND=5.64 HUMIDITY=83 TEMP=38.97 CLOUDINESS=100
# For the city named Hami, ID Number-1529484: LAT=42.84 WIND=5.03 HUMIDITY=32 TEMP=78.21 CLOUDINESS=84
# For the city named Chicama, ID Number-3698359: LAT=-7.84 WIND=8.05 HUMIDITY=88 TEMP=62.6 CLOUDINESS=90
# For the city named Colquechaca, ID Number-3919720: LAT=-18.7 WIND=15.77 HUMIDITY=50 TEMP=41.49 CLOUDINESS=68
# For the city named Kentau, ID Number-1522751: LAT=43.52 WIND=13.44 HUMIDITY=19 TEMP=87.57 CLOUDINESS=0
# For the city named Vanino, ID Number-479426: LAT=53.93 WIND=7.85 HUMIDITY=82 TEMP=68.85 CLOUDINESS=100
# For the city named Banjar, ID Number-1650233: LAT=-7.37 WIND=0.56 HUMIDITY=90 TEMP=68.49 CLOUDINESS=45
# For the city named Emerald, ID Number-2167426: LAT=-23.53 WIND=5.82 HUMIDITY=58 TEMP=59 CLOUDINESS=0
# For the city named Saint-Augustin, ID Number-6138501: LAT=45.63 WIND=8.05 HUMIDITY=60 TEMP=73 CLOUDINESS=20
# For the city named Portmore, ID Number-3488981: LAT=17.97 WIND=20.8 HUMIDITY=55 TEMP=87.8 CLOUDINESS=20
# For the city named Caconda, ID Number-3351380: LAT=-13.73 WIND=0.45 HUMIDITY=14 TEMP=85.59 CLOUDINESS=0
# For the city named Laguna, ID Number-3581398: LAT=16.17 WIND=2.33 HUMIDITY=88 TEMP=80.6 CLOUDINESS=90
# For the city named Sao Joao da Barra, ID Number-3448903: LAT=-21.64 WIND=11.41 HUMIDITY=65 TEMP=77 CLOUDINESS=40
# For the city named Ust-Kuyga, ID Number-2013921: LAT=70 WIND=7.38 HUMIDITY=52 TEMP=54.99 CLOUDINESS=47
# For the city named Seidu, ID Number-2342616: LAT=8.32 WIND=6.82 HUMIDITY=75 TEMP=81.27 CLOUDINESS=34
# For the city named Ahuimanu, ID Number-5856516: LAT=21.44 WIND=10.29 HUMIDITY=88 TEMP=80.6 CLOUDINESS=75
# For the city named Terrace Bay, ID Number-6162951: LAT=48.78 WIND=4.7 HUMIDITY=72 TEMP=60.8 CLOUDINESS=20
# For the city named Aksarka, ID Number-1512019: LAT=66.56 WIND=12.28 HUMIDITY=56 TEMP=60.93 CLOUDINESS=100
# For the city named Jining, ID Number-1805518: LAT=35.41 WIND=5.84 HUMIDITY=95 TEMP=86 CLOUDINESS=69
# For the city named Codrington, ID Number-2160063: LAT=-28.95 WIND=10.29 HUMIDITY=93 TEMP=55.99 CLOUDINESS=0
# For the city named Basco, ID Number-4863349: LAT=40.33 WIND=5.82 HUMIDITY=72 TEMP=71.6 CLOUDINESS=1
# For the city named Ramsar, ID Number-9874: LAT=36.92 WIND=2.24 HUMIDITY=74 TEMP=82.4 CLOUDINESS=75
# For the city named Narsingi, ID Number-1261750: LAT=18.04 WIND=4.7 HUMIDITY=74 TEMP=84.2 CLOUDINESS=75
# For the city named Sitka, ID Number-4267710: LAT=37.17 WIND=5.01 HUMIDITY=66 TEMP=68 CLOUDINESS=0
# For the city named Fare, ID Number-4034496: LAT=-16.7 WIND=15.05 HUMIDITY=82 TEMP=78.93 CLOUDINESS=96
# For the city named Nukus, ID Number-601294: LAT=42.46 WIND=6.93 HUMIDITY=17 TEMP=100.4 CLOUDINESS=0
# For the city named Aksay, ID Number-610613: LAT=51.17 WIND=6.38 HUMIDITY=54 TEMP=74.25 CLOUDINESS=0
# For the city named Meiganga, ID Number-2227402: LAT=6.52 WIND=1.19 HUMIDITY=92 TEMP=72.09 CLOUDINESS=100
# For the city named Rawson, ID Number-3839307: LAT=-43.3 WIND=19.77 HUMIDITY=48 TEMP=45.81 CLOUDINESS=0
# For the city named Mangan, ID Number-1263776: LAT=27.5 WIND=1.66 HUMIDITY=99 TEMP=60.57 CLOUDINESS=83
# For the city named Chuzhou, ID Number-1814757: LAT=32.25 WIND=9.82 HUMIDITY=80 TEMP=82.35 CLOUDINESS=85
# For the city named Gat, ID Number-2249901: LAT=14.69 WIND=8.05 HUMIDITY=58 TEMP=86 CLOUDINESS=0
# For the city named Naze, ID Number-2337542: LAT=5.43 WIND=7.36 HUMIDITY=86 TEMP=77.67 CLOUDINESS=100
# For the city named Ouadda, ID Number-236901: LAT=8.07 WIND=4.23 HUMIDITY=79 TEMP=78.03 CLOUDINESS=95
# For the city named Obera, ID Number-3430340: LAT=-27.49 WIND=5.57 HUMIDITY=82 TEMP=72.09 CLOUDINESS=85
# For the city named Palora, ID Number-3653523: LAT=-1.7 WIND=3.36 HUMIDITY=93 TEMP=66.2 CLOUDINESS=90
# For the city named Parau, ID Number-2193733: LAT=-36.97 WIND=1.12 HUMIDITY=100 TEMP=48.99 CLOUDINESS=85
# For the city named Isangel, ID Number-2136825: LAT=-19.55 WIND=15.73 HUMIDITY=68 TEMP=70.83 CLOUDINESS=3
# For the city named Gamba, ID Number-1281256: LAT=28.28 WIND=11.23 HUMIDITY=65 TEMP=48.15 CLOUDINESS=89
# For the city named Lorengau, ID Number-2092164: LAT=-2.02 WIND=8.03 HUMIDITY=84 TEMP=79.83 CLOUDINESS=100
# For the city named Miles City, ID Number-5666176: LAT=46.41 WIND=8.05 HUMIDITY=68 TEMP=71.01 CLOUDINESS=1
# For the city named Moron, ID Number-3720455: LAT=18.56 WIND=2.3 HUMIDITY=62 TEMP=84.15 CLOUDINESS=27
# For the city named Nakasongola, ID Number-228418: LAT=1.32 WIND=2.68 HUMIDITY=75 TEMP=76.23 CLOUDINESS=65
# For the city named Gari, ID Number-1506676: LAT=59.43 WIND=4.38 HUMIDITY=65 TEMP=69.75 CLOUDINESS=0
# For the city named Egvekinot, ID Number-4031742: LAT=66.32 WIND=2.21 HUMIDITY=96 TEMP=42.93 CLOUDINESS=100
# For the city named Pelotas, ID Number-3454244: LAT=-31.77 WIND=2.24 HUMIDITY=100 TEMP=59 CLOUDINESS=90
# For the city named Ilhabela, ID Number-3461425: LAT=-23.78 WIND=5.01 HUMIDITY=68 TEMP=73.89 CLOUDINESS=25
# For the city named Tumbotino, ID Number-480453: LAT=56 WIND=11.18 HUMIDITY=77 TEMP=73 CLOUDINESS=75
# For the city named Mar del Plata, ID Number-3863379: LAT=-46.43 WIND=18.25 HUMIDITY=56 TEMP=42.75 CLOUDINESS=0
# For the city named Iquique, ID Number-3887127: LAT=-20.22 WIND=11.41 HUMIDITY=67 TEMP=60.8 CLOUDINESS=90
# For the city named Chudniv, ID Number-710381: LAT=50.05 WIND=11.39 HUMIDITY=67 TEMP=69.03 CLOUDINESS=83
# For the city named Thinadhoo, ID Number-1337610: LAT=0.53 WIND=11.12 HUMIDITY=72 TEMP=83.97 CLOUDINESS=59
# For the city named Pishva, ID Number-120972: LAT=35.31 WIND=13.87 HUMIDITY=8 TEMP=104 CLOUDINESS=40
# For the city named Fort Saint James, ID Number-5881688: LAT=54.43 WIND=2.89 HUMIDITY=91 TEMP=54.27 CLOUDINESS=1
# For the city named Marsh Harbour, ID Number-3571913: LAT=26.54 WIND=18.9 HUMIDITY=75 TEMP=84.33 CLOUDINESS=49
# For the city named Petropavlovsk-Kamchatskiy, ID Number-2122104: LAT=53.05 WIND=6.71 HUMIDITY=87 TEMP=57.2 CLOUDINESS=40
# For the city named Alice Springs, ID Number-2077895: LAT=-23.7 WIND=4.7 HUMIDITY=32 TEMP=51.8 CLOUDINESS=0
# For the city named Gondanglegi, ID Number-1640660: LAT=-7.75 WIND=4.97 HUMIDITY=93 TEMP=67.59 CLOUDINESS=23
# For the city named Los Llanos de Aridane, ID Number-2514651: LAT=28.66 WIND=17.22 HUMIDITY=65 TEMP=77 CLOUDINESS=20
# For the city named Belmonte, ID Number-8010472: LAT=40.36 WIND=8.55 HUMIDITY=31 TEMP=98.01 CLOUDINESS=37
# For the city named Clyde River, ID Number-5924351: LAT=70.47 WIND=5.82 HUMIDITY=76 TEMP=55.4 CLOUDINESS=1
# For the city named Tekeli, ID Number-1518296: LAT=44.86 WIND=0.96 HUMIDITY=25 TEMP=71.73 CLOUDINESS=6
# For the city named Goundam, ID Number-2456917: LAT=16.42 WIND=5.73 HUMIDITY=29 TEMP=100.17 CLOUDINESS=21
# For the city named Saint-Joseph, ID Number-3037456: LAT=43.56 WIND=5.82 HUMIDITY=49 TEMP=96.8 CLOUDINESS=0
# For the city named Jalu, ID Number-86049: LAT=29.03 WIND=16.91 HUMIDITY=15 TEMP=98.91 CLOUDINESS=0
# For the city named Petawawa, ID Number-6101607: LAT=45.89 WIND=8.05 HUMIDITY=63 TEMP=69.01 CLOUDINESS=20
# For the city named Teguise, ID Number-2510573: LAT=29.06 WIND=18.34 HUMIDITY=54 TEMP=82.4 CLOUDINESS=20
# For the city named Port Macquarie, ID Number-2152659: LAT=-31.43 WIND=4.43 HUMIDITY=93 TEMP=50 CLOUDINESS=0
# For the city named Henties Bay, ID Number-3356832: LAT=-22.12 WIND=7 HUMIDITY=73 TEMP=64 CLOUDINESS=0
# For the city named San Jose, ID Number-3602137: LAT=14.25 WIND=2.59 HUMIDITY=73 TEMP=75.2 CLOUDINESS=1
# For the city named Paamiut, ID Number-3421193: LAT=61.99 WIND=3.27 HUMIDITY=97 TEMP=39.15 CLOUDINESS=100
# For the city named Whitehorse, ID Number-6180550: LAT=60.72 WIND=5.82 HUMIDITY=93 TEMP=57.2 CLOUDINESS=75
# For the city named Severo-Kurilsk, ID Number-2121385: LAT=50.68 WIND=3.6 HUMIDITY=91 TEMP=46.17 CLOUDINESS=100
# For the city named Wanning, ID Number-3220813: LAT=48.64 WIND=5.82 HUMIDITY=35 TEMP=88 CLOUDINESS=20
# For the city named Kavaratti, ID Number-1267390: LAT=10.57 WIND=20.07 HUMIDITY=76 TEMP=82.53 CLOUDINESS=100
# For the city named Beringovskiy, ID Number-2126710: LAT=63.05 WIND=1.72 HUMIDITY=80 TEMP=40.23 CLOUDINESS=79
# For the city named Warwick, ID Number-5225507: LAT=41.7 WIND=16.11 HUMIDITY=100 TEMP=66.99 CLOUDINESS=90
# For the city named Kidal, ID Number-2455290: LAT=18.44 WIND=2.55 HUMIDITY=19 TEMP=103.41 CLOUDINESS=0
# For the city named Balabac, ID Number-1728675: LAT=7.99 WIND=4.83 HUMIDITY=79 TEMP=81.45 CLOUDINESS=100
# For the city named Xining, ID Number-1788852: LAT=36.62 WIND=4.43 HUMIDITY=86 TEMP=47.43 CLOUDINESS=91
# For the city named Omboue, ID Number-2396853: LAT=-1.57 WIND=17.45 HUMIDITY=85 TEMP=74.25 CLOUDINESS=40
# For the city named Longyan, ID Number-1802276: LAT=25.1 WIND=1.72 HUMIDITY=97 TEMP=71.01 CLOUDINESS=0
# For the city named Chimbote, ID Number-3698304: LAT=-9.08 WIND=12.66 HUMIDITY=89 TEMP=62.37 CLOUDINESS=100
# For the city named Kefalos, ID Number-260308: LAT=36.75 WIND=16.11 HUMIDITY=38 TEMP=87.8 CLOUDINESS=0
# For the city named Zamora, ID Number-3104342: LAT=41.51 WIND=10.29 HUMIDITY=23 TEMP=93.2 CLOUDINESS=20
# For the city named Camacha, ID Number-2270385: LAT=33.08 WIND=13.87 HUMIDITY=69 TEMP=77 CLOUDINESS=20
# For the city named Jiuquan, ID Number-1280957: LAT=39.73 WIND=4.85 HUMIDITY=27 TEMP=72.63 CLOUDINESS=4
# For the city named Hirara, ID Number-1862505: LAT=24.8 WIND=8.75 HUMIDITY=78 TEMP=83.25 CLOUDINESS=100
# For the city named Dumas, ID Number-1255364: LAT=21.09 WIND=3.36 HUMIDITY=74 TEMP=87.8 CLOUDINESS=40
# For the city named Rocha, ID Number-3440777: LAT=-34.48 WIND=12.93 HUMIDITY=72 TEMP=54.81 CLOUDINESS=100
# For the city named Marawi, ID Number-1701054: LAT=8 WIND=7 HUMIDITY=90 TEMP=77 CLOUDINESS=100
# For the city named Trairi, ID Number-3386177: LAT=-3.28 WIND=11.88 HUMIDITY=51 TEMP=86.13 CLOUDINESS=36
# For the city named Guymon, ID Number-5515743: LAT=36.68 WIND=9.17 HUMIDITY=82 TEMP=66 CLOUDINESS=40
# For the city named Gutierrez, ID Number-3832647: LAT=-39.11 WIND=8.72 HUMIDITY=42 TEMP=46.35 CLOUDINESS=0
# For the city named Moree, ID Number-2156927: LAT=-29.46 WIND=5.82 HUMIDITY=39 TEMP=50 CLOUDINESS=0
# For the city named Faya, ID Number-110690: LAT=18.39 WIND=16.11 HUMIDITY=47 TEMP=86 CLOUDINESS=40
# For the city named Bonga, ID Number-341742: LAT=7.26 WIND=0.96 HUMIDITY=96 TEMP=65.07 CLOUDINESS=76
# For the city named Port Lincoln, ID Number-2063036: LAT=-34.72 WIND=16.49 HUMIDITY=75 TEMP=58.05 CLOUDINESS=0
# For the city named Aksu, ID Number-1524298: LAT=52.04 WIND=6.53 HUMIDITY=60 TEMP=73.4 CLOUDINESS=75
# For the city named Deputatskiy, ID Number-2028164: LAT=69.3 WIND=12.88 HUMIDITY=41 TEMP=51.57 CLOUDINESS=93
# For the city named Dzhebariki-Khaya, ID Number-2024626: LAT=62.22 WIND=2.17 HUMIDITY=55 TEMP=50.49 CLOUDINESS=0
# For the city named Mehamn, ID Number-778707: LAT=71.03 WIND=4.7 HUMIDITY=64 TEMP=68 CLOUDINESS=0
# For the city named Khandbari, ID Number-1283217: LAT=27.38 WIND=1.3 HUMIDITY=99 TEMP=60.39 CLOUDINESS=100
# For the city named Isiro, ID Number-215771: LAT=2.77 WIND=3.27 HUMIDITY=90 TEMP=74.97 CLOUDINESS=38
# For the city named Bunia, ID Number-217695: LAT=1.56 WIND=2.55 HUMIDITY=92 TEMP=71.73 CLOUDINESS=40
# For the city named Oranjestad, ID Number-3577154: LAT=12.52 WIND=21.92 HUMIDITY=74 TEMP=84.2 CLOUDINESS=20
# For the city named Gazanjyk, ID Number-161974: LAT=39.24 WIND=6.15 HUMIDITY=22 TEMP=103.95 CLOUDINESS=0
# For the city named Abomey, ID Number-2395915: LAT=7.18 WIND=7.9 HUMIDITY=79 TEMP=80.73 CLOUDINESS=97
# For the city named Sorong, ID Number-1626542: LAT=-0.86 WIND=6.22 HUMIDITY=94 TEMP=73.17 CLOUDINESS=100
# For the city named Kamyshin, ID Number-553287: LAT=50.08 WIND=10.16 HUMIDITY=39 TEMP=79.83 CLOUDINESS=83
# For the city named Elizabeth City, ID Number-4465088: LAT=36.3 WIND=11.41 HUMIDITY=70 TEMP=84.2 CLOUDINESS=75
# For the city named Pangai, ID Number-4032369: LAT=-19.8 WIND=8.9 HUMIDITY=56 TEMP=71.19 CLOUDINESS=97
# For the city named Sterling, ID Number-4787534: LAT=39 WIND=11.41 HUMIDITY=83 TEMP=70 CLOUDINESS=90
# For the city named Pereira Barreto, ID Number-3454131: LAT=-20.64 WIND=11.41 HUMIDITY=40 TEMP=81.81 CLOUDINESS=0
# For the city named Tahe, ID Number-2034615: LAT=52.34 WIND=7.05 HUMIDITY=98 TEMP=51.21 CLOUDINESS=100
# For the city named Kibala, ID Number-2425791: LAT=9.11 WIND=11.36 HUMIDITY=52 TEMP=89.6 CLOUDINESS=20
# For the city named Reforma, ID Number-4011743: LAT=24.02 WIND=14 HUMIDITY=87 TEMP=64 CLOUDINESS=20
# For the city named Suluq, ID Number-81604: LAT=31.67 WIND=16.2 HUMIDITY=72 TEMP=81.63 CLOUDINESS=0
# For the city named Praia, ID Number-3460954: LAT=-20.25 WIND=11.41 HUMIDITY=60 TEMP=68 CLOUDINESS=20
# For the city named Husavik, ID Number-5961417: LAT=50.56 WIND=4 HUMIDITY=72 TEMP=71.01 CLOUDINESS=0
# For the city named Ahome, ID Number-4019098: LAT=25.92 WIND=6.02 HUMIDITY=78 TEMP=80.01 CLOUDINESS=75
# For the city named Minot, ID Number-5690532: LAT=48.23 WIND=4.7 HUMIDITY=68 TEMP=72 CLOUDINESS=1
# For the city named Samsun, ID Number-740263: LAT=41.29 WIND=11.41 HUMIDITY=69 TEMP=81 CLOUDINESS=40
# For the city named Ibra, ID Number-287832: LAT=22.69 WIND=7.49 HUMIDITY=52 TEMP=85.23 CLOUDINESS=2
# For the city named Gradignan, ID Number-3015419: LAT=44.77 WIND=2.24 HUMIDITY=17 TEMP=106 CLOUDINESS=0
# For the city named Phalaborwa, ID Number-965528: LAT=-23.95 WIND=10.29 HUMIDITY=13 TEMP=80.6 CLOUDINESS=0
# For the city named Yangambi, ID Number-203717: LAT=0.77 WIND=3.65 HUMIDITY=57 TEMP=85.05 CLOUDINESS=95
# For the city named Anisoc, ID Number-2310309: LAT=1.87 WIND=4.34 HUMIDITY=88 TEMP=76.77 CLOUDINESS=89
# For the city named Byron Bay, ID Number-2172880: LAT=-28.65 WIND=3.36 HUMIDITY=93 TEMP=55.99 CLOUDINESS=0
# For the city named La Ronge, ID Number-6050066: LAT=55.1 WIND=2.24 HUMIDITY=77 TEMP=66.2 CLOUDINESS=20
# For the city named Manaure, ID Number-3675504: LAT=11.78 WIND=13.87 HUMIDITY=70 TEMP=86 CLOUDINESS=75
# For the city named Stonewall, ID Number-6157355: LAT=50.13 WIND=4 HUMIDITY=72 TEMP=71.01 CLOUDINESS=0
# For the city named La Sarre, ID Number-6050194: LAT=48.8 WIND=5.75 HUMIDITY=87 TEMP=50.13 CLOUDINESS=100
# For the city named Horsham, ID Number-2163055: LAT=-36.71 WIND=8.28 HUMIDITY=91 TEMP=39.87 CLOUDINESS=10
# For the city named Mahajanga, ID Number-1062663: LAT=-15.72 WIND=9.17 HUMIDITY=20 TEMP=84.2 CLOUDINESS=0
# For the city named Aripuana, ID Number-3665202: LAT=-9.17 WIND=1.92 HUMIDITY=50 TEMP=84.51 CLOUDINESS=92
# For the city named Broome, ID Number-2656067: LAT=52.47 WIND=10.29 HUMIDITY=42 TEMP=93 CLOUDINESS=20
# For the city named Mecca, ID Number-104515: LAT=21.43 WIND=15.3 HUMIDITY=14 TEMP=101.61 CLOUDINESS=0
# For the city named Pangnirtung, ID Number-6096551: LAT=66.15 WIND=6.93 HUMIDITY=100 TEMP=42.8 CLOUDINESS=90
# For the city named Seoul, ID Number-1835848: LAT=37.57 WIND=3.36 HUMIDITY=88 TEMP=82.4 CLOUDINESS=90
# For the city named Saint Lawrence, ID Number-2562619: LAT=36.06 WIND=8.05 HUMIDITY=38 TEMP=91.4 CLOUDINESS=0
# For the city named Lata, ID Number-1253628: LAT=30.78 WIND=1.23 HUMIDITY=94 TEMP=44.73 CLOUDINESS=73
# For the city named Pisco, ID Number-3932145: LAT=-13.71 WIND=8.05 HUMIDITY=30 TEMP=71.6 CLOUDINESS=90
# For the city named Portland, ID Number-4975802: LAT=43.66 WIND=4.7 HUMIDITY=87 TEMP=62.6 CLOUDINESS=90
# For the city named Makokou, ID Number-2399371: LAT=0.56 WIND=4.16 HUMIDITY=80 TEMP=78.57 CLOUDINESS=79
# For the city named Bossangoa, ID Number-2388036: LAT=6.5 WIND=5.03 HUMIDITY=93 TEMP=73.17 CLOUDINESS=100
# For the city named Luzilandia, ID Number-3396101: LAT=-3.46 WIND=6.49 HUMIDITY=59 TEMP=84.69 CLOUDINESS=78
# For the city named Vostok, ID Number-2013279: LAT=46.45 WIND=4.38 HUMIDITY=93 TEMP=67.59 CLOUDINESS=94
# For the city named Amapa, ID Number-3603330: LAT=15.09 WIND=4.7 HUMIDITY=78 TEMP=86 CLOUDINESS=75
# For the city named Seydi, ID Number-2448024: LAT=13.34 WIND=2.66 HUMIDITY=38 TEMP=90.63 CLOUDINESS=34
# For the city named Coahuayana, ID Number-3981460: LAT=18.62 WIND=0.63 HUMIDITY=90 TEMP=74.25 CLOUDINESS=98
# For the city named Grand-Lahou, ID Number-2288105: LAT=5.24 WIND=8.3 HUMIDITY=66 TEMP=81.99 CLOUDINESS=91
# For the city named Dunedin, ID Number-2191562: LAT=-45.87 WIND=11.99 HUMIDITY=82 TEMP=51.01 CLOUDINESS=11
# For the city named Okhotsk, ID Number-2122605: LAT=59.36 WIND=3.27 HUMIDITY=78 TEMP=45.99 CLOUDINESS=0
# For the city named Dukat, ID Number-3184575: LAT=40.25 WIND=1.99 HUMIDITY=54 TEMP=84 CLOUDINESS=13
# For the city named Alacranes, ID Number-3569379: LAT=22.77 WIND=2.24 HUMIDITY=74 TEMP=84.2 CLOUDINESS=20
# For the city named Strezhevoy, ID Number-1490796: LAT=60.73 WIND=2.24 HUMIDITY=64 TEMP=69.8 CLOUDINESS=0
# For the city named Gimli, ID Number-5961417: LAT=50.63 WIND=4 HUMIDITY=72 TEMP=71.01 CLOUDINESS=0
# For the city named Port Augusta, ID Number-2063056: LAT=-32.49 WIND=9.17 HUMIDITY=72 TEMP=59 CLOUDINESS=90
# For the city named San Juan, ID Number-3837213: LAT=-31.54 WIND=4.34 HUMIDITY=55 TEMP=31.59 CLOUDINESS=46
# For the city named Cordoba, ID Number-3846616: LAT=-27.78 WIND=6.8 HUMIDITY=37 TEMP=43.65 CLOUDINESS=71
# For the city named Gillette, ID Number-5826027: LAT=44.29 WIND=13.87 HUMIDITY=82 TEMP=68 CLOUDINESS=1
# For the city named Matamoros, ID Number-3523466: LAT=25.87 WIND=3.36 HUMIDITY=84 TEMP=87.01 CLOUDINESS=1
# For the city named Magole, ID Number-155334: LAT=-6.37 WIND=5.66 HUMIDITY=49 TEMP=66.87 CLOUDINESS=0
# For the city named Bucerias, ID Number-4016734: LAT=20.76 WIND=6.93 HUMIDITY=88 TEMP=80.01 CLOUDINESS=75
# For the city named San Nicolas, ID Number-1688864: LAT=16.07 WIND=5.03 HUMIDITY=87 TEMP=78.75 CLOUDINESS=100
# For the city named Yenagoa, ID Number-2318123: LAT=4.92 WIND=7.29 HUMIDITY=87 TEMP=76.95 CLOUDINESS=100
# For the city named Yar-Sale, ID Number-1486321: LAT=66.83 WIND=14.94 HUMIDITY=59 TEMP=57.69 CLOUDINESS=56

# %%
ls=[citNam, code,  lat, temp, humi, clouds, wind ]
for l in ls:
    print(len(l))

# %%
dictionary = {}
dictionary={
    "City" : citNam, 
    "ID Code" : code, 
    "Latitude" : lat, 
    "Temperature" : temp,
    "Humidity" : humi,
    "Cloudiness" : clouds,
    "Wind" : wind
}
weather_data=pd.DataFrame(dictionary)
weather_data.to_csv("output_data/weather_data.csv", index=False, header=True)
weather_data.head()

# %%
weather_data.std
weather_data.mean
weather_data.mode

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# Temperature (F) vs. Latitude
#
# Humidity (%) vs. Latitude
#
# Cloudiness (%) vs. Latitude
#
# Wind Speed (mph) vs. Latitude

# %%
latitude=weather_data['Latitude']
temperature=weather_data['Temperature']
humidity= weather_data['Humidity']
cloudiness= weather_data['Cloudiness']
wind_speed= weather_data['Wind']

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig = plt.figure()
fig1=plt.scatter(latitude, temperature, marker='.', facecolors="blue", edgecolors="blue")
# Set the upper and lower limits of our y axis
plt.ylim(0,120)
# Set the upper and lower limits of our x axis
plt.xlim(-80,100)
# Create a title, x label, and y label for our chart
plt.title("Max Temperature v Latitude")

plt.xlabel("Latitude")
plt.ylabel("Temperature (Degrees F)")

# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.savefig("output_data/temp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig = plt.figure()
fig1=plt.scatter(latitude, humidity, marker=".", facecolors="blue", edgecolors="blue")
# Set the upper and lower limits of our y axis
plt.ylim(0,105)
# Set the upper and lower limits of our x axis
plt.xlim(-80,100)
# Create a title, x label, and y label for our chart
plt.title("Humidity v Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.savefig("output_data/humidity_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig = plt.figure()
fig1=plt.scatter(latitude, cloudiness, marker=".", facecolors="blue", edgecolors="blue")
# Set the upper and lower limits of our y axis
plt.ylim(-5,105)
# Set the upper and lower limits of our x axis
plt.xlim(-80,100)
# Create a title, x label, and y label for our chart
plt.title("Cloudiness v Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.savefig("output_data/cloudiness_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig = plt.figure()
fig1=plt.scatter(latitude, wind_speed, marker=".", facecolors="blue", edgecolors="blue")
# Set the upper and lower limits of our y axis
plt.ylim(0,40)
# Set the upper and lower limits of our x axis
plt.xlim(-80,100)
# Create a title, x label, and y label for our chart
plt.title("Wind Speed v Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.savefig("output_data/wind_speed_v_Latitude.png")
plt.show()
